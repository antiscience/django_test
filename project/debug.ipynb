# %%
import os

os.environ.setdefault('DJANGO_SETTINGS_MODULE', 'project.settings')
os.environ["DJANGO_ALLOW_ASYNC_UNSAFE"] = "true"

import django
django.setup()

# %%
import pandas as pd

df = pd.read_csv('./results.csv')
df = df[(df.tournament == 'UEFA Euro') & (df.date > '2024-01-01')]
df.head()
# Out:
#              date home_team    away_team  home_score  away_score tournament  \
# 47075  2024-06-14   Germany     Scotland         NaN         NaN  UEFA Euro
# 47076  2024-06-15   Hungary  Switzerland         NaN         NaN  UEFA Euro
# 47077  2024-06-15     Spain      Croatia         NaN         NaN  UEFA Euro
# 47078  2024-06-15     Italy      Albania         NaN         NaN  UEFA Euro
# 47079  2024-06-16  Slovenia      Denmark         NaN         NaN  UEFA Euro
#
#             city  country  neutral
# 47075     Munich  Germany    False
# 47076    Cologne  Germany     True
# 47077     Berlin  Germany     True
# 47078   Dortmund  Germany     True
# 47079  Stuttgart  Germany     True

# %%
teams = sorted(list(set(df['home_team'].dropna()) | set(df["away_team"].dropna())))
teams
# Out:
# ['Albania',
#  'Austria',
#  'Belgium',
#  'Croatia',
#  'Czech Republic',
#  'Denmark',
#  'England',
#  'France',
#  'Georgia',
#  'Germany',
#  'Hungary',
#  'Italy',
#  'Netherlands',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Scotland',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Switzerland',
#  'Turkey',
#  'Ukraine']

# %%
groups = pd.read_csv('./groups.csv')
groups
# Out:
#     Stage Group            Team
# 0   Group     A         Germany
# 1   Group     A        Scotland
# 2   Group     A         Hungary
# 3   Group     A     Switzerland
# 4   Group     B           Spain
# 5   Group     B         Croatia
# 6   Group     B           Italy
# 7   Group     B         Albania
# 8   Group     C        Slovenia
# 9   Group     C         Denmark
# 10  Group     C          Serbia
# 11  Group     C         England
# 12  Group     D          Poland
# 13  Group     D     Netherlands
# 14  Group     D         Austria
# 15  Group     D          France
# 16  Group     E         Belgium
# 17  Group     E        Slovakia
# 18  Group     E         Romania
# 19  Group     E         Ukraine
# 20  Group     F          Turkey
# 21  Group     F         Georgia
# 22  Group     F        Portugal
# 23  Group     F  Czech Republic

# %%
from football.models import Team, Group, Match, Bet, Tournament

# %%
uefa2024 = Tournament()
uefa2024.name = 'European Soccer Championship UEFA 2024'
uefa2024.save()

# %%
uefa2024 = Tournament.objects.all()[0]
uefa2024
# Out:
# <Tournament: Tournament object (1)>

# %%
Group.objects.all().delete()
for name in Group.GROUP_NAMES:
    g = Group(name=name, tournament=uefa2024)
    g.save()

# %%
for g in Group.objects.all():
    print(g.name, g.tournament.name)
# Out:
# A European Soccer Championship UEFA 2024
# B European Soccer Championship UEFA 2024
# C European Soccer Championship UEFA 2024
# D European Soccer Championship UEFA 2024
# E European Soccer Championship UEFA 2024
# F European Soccer Championship UEFA 2024

# %%
teams
# Out:
# ['Albania',
#  'Austria',
#  'Belgium',
#  'Croatia',
#  'Czech Republic',
#  'Denmark',
#  'England',
#  'France',
#  'Georgia',
#  'Germany',
#  'Hungary',
#  'Italy',
#  'Netherlands',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Scotland',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Switzerland',
#  'Turkey',
#  'Ukraine']

# %%
Group.objects.all().values()
# Out:
# <QuerySet [{'id': 13, 'name': 'A', 'tournament_id': 1}, {'id': 14, 'name': 'B', 'tournament_id': 1}, {'id': 15, 'name': 'C', 'tournament_id': 1}, {'id': 16, 'name': 'D', 'tournament_id': 1}, {'id': 17, 'name': 'E', 'tournament_id': 1}, {'id': 18, 'name': 'F', 'tournament_id': 1}]>

# %%
group_objects = Group.objects.all()
Team.objects.all().delete()

for i, team in enumerate(teams):
    group_name = groups[groups.Team == team].iloc[0].Group
    group = group_objects.get(name = group_name)
    Team(id=i, name=team, group=group).save()

for team in Team.objects.all():
    print(team.id, team.name, team.group.name)
# Out:
# 0 Albania B
# 1 Austria D
# 2 Belgium E
# 3 Croatia B
# 4 Czech Republic F
# 5 Denmark C
# 6 England C
# 7 France D
# 8 Georgia F
# 9 Germany A
# 10 Hungary A
# 11 Italy B
# 12 Netherlands D
# 13 Poland D
# 14 Portugal F
# 15 Romania E
# 16 Scotland A
# 17 Serbia C
# 18 Slovakia E
# 19 Slovenia C
# 20 Spain B
# 21 Switzerland A
# 22 Turkey F
# 23 Ukraine E

# %%
vorrunde = df[:36]
vorrunde
# Out:
#              date       home_team       away_team  home_score  away_score  \
# 47075  2024-06-14         Germany        Scotland         NaN         NaN
# 47076  2024-06-15         Hungary     Switzerland         NaN         NaN
# 47077  2024-06-15           Spain         Croatia         NaN         NaN
# 47078  2024-06-15           Italy         Albania         NaN         NaN
# 47079  2024-06-16        Slovenia         Denmark         NaN         NaN
# 47080  2024-06-16          Serbia         England         NaN         NaN
# 47081  2024-06-16          Poland     Netherlands         NaN         NaN
# 47082  2024-06-17         Austria          France         NaN         NaN
# 47083  2024-06-17         Romania         Ukraine         NaN         NaN
# 47084  2024-06-17         Belgium        Slovakia         NaN         NaN
# 47085  2024-06-18          Turkey         Georgia         NaN         NaN
# 47086  2024-06-18        Portugal  Czech Republic         NaN         NaN
# 47087  2024-06-19         Germany         Hungary         NaN         NaN
# 47088  2024-06-19        Scotland     Switzerland         NaN         NaN
# 47089  2024-06-19         Croatia         Albania         NaN         NaN
# 47090  2024-06-20           Spain           Italy         NaN         NaN
# 47091  2024-06-20        Slovenia          Serbia         NaN         NaN
# 47092  2024-06-20         Denmark         England         NaN         NaN
# 47093  2024-06-21          Poland         Austria         NaN         NaN
# 47094  2024-06-21     Netherlands          France         NaN         NaN
# 47095  2024-06-21        Slovakia         Ukraine         NaN         NaN
# 47096  2024-06-22         Belgium         Romania         NaN         NaN
# 47097  2024-06-22         Georgia  Czech Republic         NaN         NaN
# 47098  2024-06-22          Turkey        Portugal         NaN         NaN
# 47099  2024-06-23         Germany     Switzerland         NaN         NaN
# 47100  2024-06-23        Scotland         Hungary         NaN         NaN
# 47101  2024-06-24         Albania           Spain         NaN         NaN
# 47102  2024-06-24         Croatia           Italy         NaN         NaN
# 47103  2024-06-25         England        Slovenia         NaN         NaN
# 47104  2024-06-25         Denmark          Serbia         NaN         NaN
# 47105  2024-06-25     Netherlands         Austria         NaN         NaN
# 47106  2024-06-25          France          Poland         NaN         NaN
# 47107  2024-06-26        Slovakia         Romania         NaN         NaN
# 47108  2024-06-26         Ukraine         Belgium         NaN         NaN
# 47109  2024-06-26         Georgia        Portugal         NaN         NaN
# 47110  2024-06-26  Czech Republic          Turkey         NaN         NaN
#
#       tournament           city  country  neutral
# 47075  UEFA Euro         Munich  Germany    False
# 47076  UEFA Euro        Cologne  Germany     True
# 47077  UEFA Euro         Berlin  Germany     True
# 47078  UEFA Euro       Dortmund  Germany     True
# 47079  UEFA Euro      Stuttgart  Germany     True
# 47080  UEFA Euro  Gelsenkirchen  Germany     True
# 47081  UEFA Euro        Hamburg  Germany     True
# 47082  UEFA Euro     Düsseldorf  Germany     True
# 47083  UEFA Euro         Munich  Germany     True
# 47084  UEFA Euro      Frankfurt  Germany     True
# 47085  UEFA Euro       Dortmund  Germany     True
# 47086  UEFA Euro        Leipzig  Germany     True
# 47087  UEFA Euro      Stuttgart  Germany    False
# 47088  UEFA Euro        Cologne  Germany     True
# 47089  UEFA Euro        Hamburg  Germany     True
# 47090  UEFA Euro  Gelsenkirchen  Germany     True
# 47091  UEFA Euro         Munich  Germany     True
# 47092  UEFA Euro      Frankfurt  Germany     True
# 47093  UEFA Euro         Berlin  Germany     True
# 47094  UEFA Euro        Leipzig  Germany     True
# 47095  UEFA Euro     Düsseldorf  Germany     True
# 47096  UEFA Euro        Cologne  Germany     True
# 47097  UEFA Euro        Hamburg  Germany     True
# 47098  UEFA Euro       Dortmund  Germany     True
# 47099  UEFA Euro      Frankfurt  Germany    False
# 47100  UEFA Euro      Stuttgart  Germany     True
# 47101  UEFA Euro     Düsseldorf  Germany     True
# 47102  UEFA Euro        Leipzig  Germany     True
# 47103  UEFA Euro        Cologne  Germany     True
# 47104  UEFA Euro         Munich  Germany     True
# 47105  UEFA Euro         Berlin  Germany     True
# 47106  UEFA Euro       Dortmund  Germany     True
# 47107  UEFA Euro      Frankfurt  Germany     True
# 47108  UEFA Euro      Stuttgart  Germany     True
# 47109  UEFA Euro  Gelsenkirchen  Germany     True
# 47110  UEFA Euro        Hamburg  Germany     True

# %%
from datetime import datetime

datum = vorrunde['date']
home_teams = vorrunde['home_team']
away_teams = vorrunde['away_team']

# %%
Match.objects.all().delete()

for m in Match.objects.all():
    print(m.id, m.home_team.name, m.away_team.name)

# %%
team_objects = Team.objects.all()
matches = [{ "date": datetime.strptime(date, '%Y-%m-%d').date(),
             "home_team": team_objects.get(name = home_team),
             "away_team": team_objects.get(name = away_team),
             "match_type": Match.MATCH_TYPES["PRELIMINARY"],
             "tournament": uefa2024
           }
           for date, home_team, away_team 
           in zip(vorrunde.date, vorrunde.home_team, vorrunde.away_team) ]

# %%
for match in matches:
    Match(**match).save()

# %%
for m in Match.objects.all():
    print(m.id, m.date, m.match_type, m.home_team.name,':', m.away_team.name)
# Out:
# 37 2024-06-14 preliminary Germany : Scotland
# 38 2024-06-15 preliminary Hungary : Switzerland
# 39 2024-06-15 preliminary Spain : Croatia
# 40 2024-06-15 preliminary Italy : Albania
# 41 2024-06-16 preliminary Slovenia : Denmark
# 42 2024-06-16 preliminary Serbia : England
# 43 2024-06-16 preliminary Poland : Netherlands
# 44 2024-06-17 preliminary Austria : France
# 45 2024-06-17 preliminary Romania : Ukraine
# 46 2024-06-17 preliminary Belgium : Slovakia
# 47 2024-06-18 preliminary Turkey : Georgia
# 48 2024-06-18 preliminary Portugal : Czech Republic
# 49 2024-06-19 preliminary Germany : Hungary
# 50 2024-06-19 preliminary Scotland : Switzerland
# 51 2024-06-19 preliminary Croatia : Albania
# 52 2024-06-20 preliminary Spain : Italy
# 53 2024-06-20 preliminary Slovenia : Serbia
# 54 2024-06-20 preliminary Denmark : England
# 55 2024-06-21 preliminary Poland : Austria
# 56 2024-06-21 preliminary Netherlands : France
# 57 2024-06-21 preliminary Slovakia : Ukraine
# 58 2024-06-22 preliminary Belgium : Romania
# 59 2024-06-22 preliminary Georgia : Czech Republic
# 60 2024-06-22 preliminary Turkey : Portugal
# 61 2024-06-23 preliminary Germany : Switzerland
# 62 2024-06-23 preliminary Scotland : Hungary
# 63 2024-06-24 preliminary Albania : Spain
# 64 2024-06-24 preliminary Croatia : Italy
# 65 2024-06-25 preliminary England : Slovenia
# 66 2024-06-25 preliminary Denmark : Serbia
# 67 2024-06-25 preliminary Netherlands : Austria
# 68 2024-06-25 preliminary France : Poland
# 69 2024-06-26 preliminary Slovakia : Romania
# 70 2024-06-26 preliminary Ukraine : Belgium
# 71 2024-06-26 preliminary Georgia : Portugal
# 72 2024-06-26 preliminary Czech Republic : Turkey

# %%
tournament = Tournament.objects.all()[0]
for m in tournament.match_set.all():
    print(m.id,m.match_type, m.date, m.home_team.name, ':', m.away_team.name)
# Out:
# 37 preliminary 2024-06-14 Germany : Scotland
# 38 preliminary 2024-06-15 Hungary : Switzerland
# 39 preliminary 2024-06-15 Spain : Croatia
# 40 preliminary 2024-06-15 Italy : Albania
# 41 preliminary 2024-06-16 Slovenia : Denmark
# 42 preliminary 2024-06-16 Serbia : England
# 43 preliminary 2024-06-16 Poland : Netherlands
# 44 preliminary 2024-06-17 Austria : France
# 45 preliminary 2024-06-17 Romania : Ukraine
# 46 preliminary 2024-06-17 Belgium : Slovakia
# 47 preliminary 2024-06-18 Turkey : Georgia
# 48 preliminary 2024-06-18 Portugal : Czech Republic
# 49 preliminary 2024-06-19 Germany : Hungary
# 50 preliminary 2024-06-19 Scotland : Switzerland
# 51 preliminary 2024-06-19 Croatia : Albania
# 52 preliminary 2024-06-20 Spain : Italy
# 53 preliminary 2024-06-20 Slovenia : Serbia
# 54 preliminary 2024-06-20 Denmark : England
# 55 preliminary 2024-06-21 Poland : Austria
# 56 preliminary 2024-06-21 Netherlands : France
# 57 preliminary 2024-06-21 Slovakia : Ukraine
# 58 preliminary 2024-06-22 Belgium : Romania
# 59 preliminary 2024-06-22 Georgia : Czech Republic
# 60 preliminary 2024-06-22 Turkey : Portugal
# 61 preliminary 2024-06-23 Germany : Switzerland
# 62 preliminary 2024-06-23 Scotland : Hungary
# 63 preliminary 2024-06-24 Albania : Spain
# 64 preliminary 2024-06-24 Croatia : Italy
# 65 preliminary 2024-06-25 England : Slovenia
# 66 preliminary 2024-06-25 Denmark : Serbia
# 67 preliminary 2024-06-25 Netherlands : Austria
# 68 preliminary 2024-06-25 France : Poland
# 69 preliminary 2024-06-26 Slovakia : Romania
# 70 preliminary 2024-06-26 Ukraine : Belgium
# 71 preliminary 2024-06-26 Georgia : Portugal
# 72 preliminary 2024-06-26 Czech Republic : Turkey

# %%
from django.contrib.auth.models import User
import random
user = User.objects.get(username = "test")
matches = Match.objects.filter(home_team__name="Germany")

for match in matches:
    bet = Bet(user=user, home_goals = random.randint(0, 10), away_goals = random.randint(0, 10), match=match)
    bet.save()

# %%
import json
matches = Match.objects.all().order_by("date")
bets = {  bet.match.id:(bet.home_goals, bet.away_goals) for bet in Bet.objects.filter(user_id = 2) }
data = []
for match in matches:
    m = match.serialize()
    if match.id in bets:
        m |= { "bet": bets[match.id] }
    data.append(m)
    
print(json.dumps(data))
# Out:
# [{"id": 37, "date": "2024-06-14", "home_team": {"code": "DE", "name": "Germany"}, "home_goals": 0, "away_team": {"code": "SC", "name": "Scotland"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024", "bet": [11, 42]}, {"id": 38, "date": "2024-06-15", "home_team": {"code": "HU", "name": "Hungary"}, "home_goals": 0, "away_team": {"code": "CH", "name": "Switzerland"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024", "bet": [11, 22]}, {"id": 39, "date": "2024-06-15", "home_team": {"code": "ES", "name": "Spain"}, "home_goals": 0, "away_team": {"code": "HR", "name": "Croatia"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024", "bet": [2, 3]}, {"id": 40, "date": "2024-06-15", "home_team": {"code": "IT", "name": "Italy"}, "home_goals": 0, "away_team": {"code": "AL", "name": "Albania"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024", "bet": [2, 5]}, {"id": 41, "date": "2024-06-16", "home_team": {"code": "SI", "name": "Slovenia"}, "home_goals": 0, "away_team": {"code": "DK", "name": "Denmark"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024", "bet": [3, 5]}, {"id": 42, "date": "2024-06-16", "home_team": {"code": "RS", "name": "Serbia"}, "home_goals": 0, "away_team": {"code": "GB", "name": "England"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024"}, {"id": 43, "date": "2024-06-16", "home_team": {"code": "PL", "name": "Poland"}, "home_goals": 0, "away_team": {"code": "NL", "name": "Netherlands"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024"}, {"id": 44, "date": "2024-06-17", "home_team": {"code": "AT", "name": "Austria"}, "home_goals": 0, "away_team": {"code": "FR", "name": "France"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024", "bet": [4, 2]}, {"id": 45, "date": "2024-06-17", "home_team": {"code": "RO", "name": "Romania"}, "home_goals": 0, "away_team": {"code": "UA", "name": "Ukraine"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024"}, {"id": 46, "date": "2024-06-17", "home_team": {"code": "BE", "name": "Belgium"}, "home_goals": 0, "away_team": {"code": "SK", "name": "Slovakia"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024", "bet": [0, 2]}, {"id": 47, "date": "2024-06-18", "home_team": {"code": "TR", "name": "Turkey"}, "home_goals": 0, "away_team": {"code": "GE", "name": "Georgia"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024"}, {"id": 48, "date": "2024-06-18", "home_team": {"code": "PT", "name": "Portugal"}, "home_goals": 0, "away_team": {"code": "CZ", "name": "Czech Republic"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024"}, {"id": 49, "date": "2024-06-19", "home_team": {"code": "DE", "name": "Germany"}, "home_goals": 0, "away_team": {"code": "HU", "name": "Hungary"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024", "bet": [7, 0]}, {"id": 50, "date": "2024-06-19", "home_team": {"code": "SC", "name": "Scotland"}, "home_goals": 0, "away_team": {"code": "CH", "name": "Switzerland"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024"}, {"id": 51, "date": "2024-06-19", "home_team": {"code": "HR", "name": "Croatia"}, "home_goals": 0, "away_team": {"code": "AL", "name": "Albania"}, "away_goals": 0, "match_type": "preliminary", "tournament": "European Soccer Championship UEFA 2024"}, {"id": 52, "date": "2024-06-20", "home_team": {"code": "ES", "name": "Spain"}, "home_goals": 0, "away_team": {"code": "IT",  ...

# %%
from datetime import datetime, date, time
from zoneinfo import ZoneInfo

match = Match.objects.all().order_by("date")[0]
end_time = time(13, 0)
current_date = datetime.now()
print(current_date)
print(datetime.combine(match.date, end_time))
print(current_date.tzinfo)

print(os.environ['TZ'])

datetime.combine(match.date, end_time) < current_date
# Out:
# 2024-06-16 18:29:47.219243
# 2024-06-14 13:00:00
# None
# UTC
# True

# %%
# sc = Team.objects.get(name = "Scotland")
# sc.code = "GB-SCT"
# sc.save()

Team.objects.get(name = "Scotland").code
# Out:
# 'GB-SCT'
